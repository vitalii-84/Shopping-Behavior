# %% [markdown]
# # Аналіз даних про поведінку покупців
#
# Проведемо аналіз, як вік, стать та дохід впливають на купівельні звички та вибір товару.
#
#
#
# ## 🧩 1. Вступ
#
#
# Метою цього проєкту є аналіз поведінки покупців на основі їхніх демографічних та поведінкових характеристик.
# Я досліджую, як вік, стать, масце проживання покупця, типи покупок та інші фактори впливають на купівельні звички, вибір товару, середній чек і використання знижок чи промокодів.
#
# Результати цього аналізу допоможуть:
#
# - краще зрозуміти профіль покупців із різних груп;
# - виявити основні чинники, що впливають на частоту покупок та середню суму витрат;
# - сформувати базові рекомендації для маркетологів щодо персоналізації пропозицій і збільшення лояльності клієнтів.
#
# Дані для аналізу взяті з Kaggle — [Shopping Behavior Dataset](https://www.kaggle.com/datasets/ahmadrazakashif/shopping-behavior-dataset/data).
#
#
#
# ## 📊 2. Огляд даних
#
# У цьому проєкті використовується датасет "Shopping Behavior Dataset", який містить інформацію про покупців і їхню поведінку під час покупок.
#
# Набір даних містить наступні стовпці:
#
# - Customer ID — унікальний ідентифікатор покупця;
# - Gender — стать покупця (Male / Female);
# - Age — вік покупця;
# - Item Purchased - придбаний товар;
# - Category - категорія придбаного товару;
# - Purchase Amount (USD) - сума покупки (USD);
# - Location - розташування покупців (штат США);
# - Size - розмір придбаного товару;
# - Color - колір придбаного товару;
# - Season - сезон для якого призначений товар;
# - Review Rating - рейтинг відгуків, який залишив покупець;
# - Subscription Status - стан підписки (чи є покупець підписником магазину);
# - Shipping Type - тип доставки;
# - Discount Applied - статус застосування знижки при покупці;
# - Promo Code Used - використаний промокод (Yes/No);
# - Previous Purchases - сума попередньої покупки;
# - Payment Method - спосіб оплати;
# - Frequency of Purchases - частота покупок.
#
# Дані не містять персональної інформації, а лише узагальнені профілі покупців.
# Це дозволяє безпечно аналізувати поведінкові тенденції.
#
# ## 🧮 3. Аналіз даних
#
# Для аналізу я планую використовувати такі бібліотеки Python:
#
# - **Pandas** — для завантаження, обробки та очищення даних (фільтрація, групування, зведені таблиці).
# - **NumPy** — для математичних обчислень (наприклад, обчислення середніх значень і стандартних відхилень).
# - **Matplotlib** — для побудови базових графіків (гістограми, діаграми).
# - **Seaborn** — для створення більш естетичних і статистичних візуалізацій (кореляційні графіки, теплові карти).
# - **Sweetviz** або **YData Profiling** — для автоматичного створення звіту про дані.
#
# План аналізу:
#
# - Завантажити та переглянути дані (перевірити пропуски, типи даних).
# - Перевірка якості даних — пошук аномалій, типів змінних.
# - Описова статистика — аналіз середніх значень, розподілів за статтю, віком, сумами покупок.
# - Візуалізація взаємозв’язків між основними змінними: вік ↔ витрати, стать ↔ категорія товарів, знижки ↔ обсяг покупок.
# - Порівняльний аналіз між підписниками та непідписниками магазину, між тими, хто використовує промокоди, і тими, хто — ні.
# - Побудувати висновки на основі отриманих результатів.
#
#
# ## 📈 4. Результати
#
# У результаті аналізу очікується отримати:
#
# - визначення груп клієнтів з високими та низькими витратами;
# - візуалізації, що демонструють поведінкові відмінності між чоловіками та жінками;
# - популярні категорії товарів для різних вікових груп.
# - вплив знижок, промокодів і типу доставки на суму покупки;
# - відмінності у поведінці між підписниками магазину та звичайними клієнтами;
# - візуалізації, які відображають закономірності у витратах та частоті покупок;
# - рекомендації щодо того, які фактори найбільше впливають на середній чек.
#
#
# ## 🧠 5. Висновки
#
# Після проведення аналізу можна буде зробити такі висновки:
#
# - як демографічні характеристики (вік і стать) безпосередньо впливають на поведінку покупців;
# - які групи клієнтів витрачають найбільше;
# - які категорії товарів мають найвищий попит серед різних демографічних груп;
# - чи суттєво підвищує ймовірність повторних покупок використання знижок та промокодів ;
# - чи підписники магазину демонструють вищу частоту покупок і більшу лояльність;
# - які рекомендації можна надати маркетологам для сегментації клієнтів, персоналізації пропозицій та підвищення ефективності продажів.
